# %% [markdown]
# # Marconi

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Single Features Analysis

# %%
# Load Data
df = pd.read_json('./single_feature_metrics.json')
df
# Out:
#                   f1_score
# all               0.522328
# ambient           0.282704
# boottime          0.016648
# bytes_in          0.495731
# bytes_out         0.016648
# ...                    ...
# ps1_output_curre  0.394627
# ps1_output_volta  0.468948
# swap_free         0.016648
# swap_total        0.495731
# total_power       0.016648
#
# [116 rows x 1 columns]

# %%
# Display top 20 best features
df.sort_values('f1_score', ascending=False).head(20)
# Out:
#                f1_score
# cpu_system     0.531236
# all            0.522328
# part_max_used  0.518622
# cpu_aidle      0.517048
# proc_total     0.502542
# fan2_0         0.495731
# swap_total     0.495731
# mem_shared     0.495731
# mem_free       0.495731
# mem_cached     0.495731
# mem_buffers    0.495731
# gv100card4     0.495731
# gv100card3     0.495731
# gv100card1     0.495731
# gv100card0     0.495731
# mem_total      0.495731
# cpu_steal      0.495731
# cpu_num        0.495731
# cpu_speed      0.495731
# bytes_in       0.495731

# %%
# Display features of interest
features = [f for f in df.index if 'load' in f or 'idle' in f] + ['all']
df.loc[features].sort_values('f1_score', ascending = False)
# Out:
#               f1_score
# all           0.522328
# cpu_aidle     0.517048
# cpu_idle      0.448587
# load_fifteen  0.447950
# load_five     0.447405
# load_one      0.446317
